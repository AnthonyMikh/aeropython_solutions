# %%
# %run -i ./../common/common
# %run -i ./../source_sink/source
# %run -i ./vortex
# %matplotlib inline

# %%
N = 50
rect = Rect(-2.0, 2.0, -1.0, 1.0)
grid = rect.make_grid(N)

# %%
vortex = Vortex(0.0, 0.0, 5.0)

# %%
size = 10

# %%
vel_vortex = vortex.velocity(grid)

# %%
setup_fig(rect, size)
streamplot_with(*grid, *vel_vortex, override={'arrowsize': 1})
plt.scatter(*vortex.coords, **scatter_params)

# %%
sink = Source(*vortex.coords, -1.0)
vel_sink = sink.velocity(grid)

# %%
vel = sum_pair(vel_vortex, vel_sink)

setup_fig(rect, size)
streamplot_with(*grid, *vel, override={'arrowsize': 1})
plt.scatter(*vortex.coords, **scatter_params)
